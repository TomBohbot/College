# %%
"""
    A simple neural network written in Keras (TensorFlow backend) to classify the IRIS data
"""

import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

iris_data = load_iris() # load the iris dataset

print('Example data: ')
print(iris_data.data[:5])
print('Example labels: ')
print(iris_data.target[:5])

x = iris_data.data[:, :2]
y_ = iris_data.target.reshape(-1, 1) == 0 # Convert data to a single column #== 0 makes it a setosa as 1 and other flower as 0.

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(5,2), activation='relu', name='fc1'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(2, activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)

# Test on unseen data

results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Example data:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Example labels:
# [0 0 0 0 0]
# Neural Network Model Summary:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 5, 10)             30
# _________________________________________________________________
# fc2 (Dense)                  (None, 5, 10)             110
# _________________________________________________________________
# output (Dense)               (None, 5, 2)              22
# =================================================================
# Total params: 162
# Trainable params: 162
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# WARNING:tensorflow:Model was constructed with shape (None, 5, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5, 2), dtype=tf.float32, name='fc1_input'), name='fc1_input', description="created by layer 'fc1_input'"), but it was called on an input with incompatible shape (5, 2).
# WARNING:tensorflow:Model was constructed with shape (None, 5, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5, 2), dtype=tf.float32, name='fc1_input'), name='fc1_input', description="created by layer 'fc1_input'"), but it was called on an input with incompatible shape (5, 2).
# 24/24 - 1s - loss: 0.6364 - accuracy: 0.6917
# Epoch 2/200
# 24/24 - 0s - loss: 0.5984 - accuracy: 0.6917
# Epoch 3/200
# 24/24 - 0s - loss: 0.5822 - accuracy: 0.6917
# Epoch 4/200
# 24/24 - 0s - loss: 0.5641 - accuracy: 0.6917
# Epoch 5/200
# 24/24 - 0s - loss: 0.5505 - accuracy: 0.6917
# Epoch 6/200
# 24/24 - 0s - loss: 0.5379 - accuracy: 0.6917
# Epoch 7/200
# 24/24 - 0s - loss: 0.5285 - accuracy: 0.6917
# Epoch 8/200
# 24/24 - 0s - loss: 0.5193 - accuracy: 0.6917
# Epoch 9/200
# 24/24 - 0s - loss: 0.5056 - accuracy: 0.6917
# Epoch 10/200
# 24/24 - 0s - loss: 0.4936 - accuracy: 0.6917
# Epoch 11/200
# 24/24 - 0s - loss: 0.4816 - accuracy: 0.6917
# Epoch 12/200
# 24/24 - 0s - loss: 0.4758 - accuracy: 0.6917
# Epoch 13/200
# 24/24 - 0s - loss: 0.4549 - accuracy: 0.6917
# Epoch 14/200
# 24/24 - 0s - loss: 0.4455 - accuracy: 0.6917
# Epoch 15/200
# 24/24 - 0s - loss: 0.4328 - accuracy: 0.6917
# Epoch 16/200
# 24/24 - 0s - loss: 0.4174 - accuracy: 0.7417
# Epoch 17/200
# 24/24 - 0s - loss: 0.4041 - accuracy: 0.7833
# Epoch 18/200
# 24/24 - 0s - loss: 0.3906 - accuracy: 0.8333
# Epoch 19/200
# 24/24 - 0s - loss: 0.3782 - accuracy: 0.8167
# Epoch 20/200
# 24/24 - 0s - loss: 0.3632 - accuracy: 0.9083
# Epoch 21/200
# 24/24 - 0s - loss: 0.3485 - accuracy: 0.9417
# Epoch 22/200
# 24/24 - 0s - loss: 0.3350 - accuracy: 0.9167
# Epoch 23/200
# 24/24 - 0s - loss: 0.3233 - accuracy: 0.9333
# Epoch 24/200
# 24/24 - 0s - loss: 0.3080 - accuracy: 0.9500
# Epoch 25/200
# 24/24 - 0s - loss: 0.2971 - accuracy: 0.9667
# Epoch 26/200
# 24/24 - 0s - loss: 0.2852 - accuracy: 0.9750
# Epoch 27/200
# 24/24 - 0s - loss: 0.2697 - accuracy: 0.9583
# Epoch 28/200
# 24/24 - 0s - loss: 0.2595 - accuracy: 0.9667
# Epoch 29/200
# 24/24 - 0s - loss: 0.2475 - accuracy: 0.9750
# Epoch 30/200
# 24/24 - 0s - loss: 0.2354 - accuracy: 0.9750
# Epoch 31/200
# 24/24 - 0s - loss: 0.2254 - accuracy: 0.9833
# Epoch 32/200
# 24/24 - 0s - loss: 0.2160 - accuracy: 0.9833
# Epoch 33/200
# 24/24 - 0s - loss: 0.2063 - accuracy: 0.9917
# Epoch 34/200
# 24/24 - 0s - loss: 0.1980 - accuracy: 0.9833
# Epoch 35/200
# 24/24 - 0s - loss: 0.1873 - accuracy: 0.9833
# Epoch 36/200
# 24/24 - 0s - loss: 0.1820 - accuracy: 0.9917
# Epoch 37/200
# 24/24 - 0s - loss: 0.1723 - accuracy: 0.9917
# Epoch 38/200
# 24/24 - 0s - loss: 0.1672 - accuracy: 0.9917
# Epoch 39/200
# 24/24 - 0s - loss: 0.1594 - accuracy: 0.9917
# Epoch 40/200
# 24/24 - 0s - loss: 0.1525 - accuracy: 0.9917
# Epoch 41/200
# 24/24 - 0s - loss: 0.1473 - accuracy: 0.9917
# Epoch 42/200
# 24/24 - 0s - loss: 0.1413 - accuracy: 0.9917
# Epoch 43/200
# 24/24 - 0s - loss: 0.1359 - accuracy: 0.9917
# Epoch 44/200
# 24/24 - 0s - loss: 0.1315 - accuracy: 0.9917
# Epoch 45/200
# 24/24 - 0s - loss: 0.1256 - accuracy: 0.9917
# Epoch 46/200
# 24/24 - 0s - loss: 0.1216 - accuracy: 0.9917
# Epoch 47/200
# 24/24 - 0s - loss: 0.1179 - accuracy: 0.9917
# Epoch 48/200
# 24/24 - 0s - loss: 0.1140 - accuracy: 0.9917
# Epoch 49/200
# 24/24 - 0s - loss: 0.1127 - accuracy: 0.9917
# Epoch 50/200
# 24/24 - 0s - loss: 0.1073 - accuracy: 0.9917
# Epoch 51/200
# 24/24 - 0s - loss: 0.1022 - accuracy: 0.9917
# Epoch 52/200
# 24/24 - 0s - loss: 0.1006 - accuracy: 0.9917
# Epoch 53/200
# 24/24 - 0s - loss: 0.0967 - accuracy: 0.9917
# Epoch 54/200
# 24/24 - 0s - loss: 0.0939 - accuracy: 0.9917
# Epoch 55/200
# 24/24 - 0s - loss: 0.0916 - accuracy: 0.9917
# Epoch 56/200
# 24/24 - 0s - loss: 0.0914 - accuracy: 0.9917
# Epoch 57/200
# 24/24 - 0s - loss: 0.0879 - accuracy: 0.9917
# Epoch 58/200
# 24/24 - 0s - loss: 0.0843 - accuracy: 0.9917
# Epoch 59/200
# 24/24 - 0s - loss: 0.0825 - accuracy: 0.9917
# Epoch 60/200
# 24/24 - 0s - loss: 0.0807 - accuracy: 0.9917
# Epoch 61/200
# 24/24 - 0s - loss: 0.0792 - accuracy: 0.9917
# Epoch 62/200
# 24/24 - 0s - loss: 0.0773 - accuracy: 0.9917
# Epoch 63/200
# 24/24 - 0s - loss: 0.0752 - accuracy: 0.9917
# Epoch 64/200
# 24/24 - 0s - loss: 0.0745 - accuracy: 0.9917
# Epoch 65/200
# 24/24 - 0s - loss: 0.0721 - accuracy: 0.9917
# Epoch 66/200
# 24/24 - 0s - loss: 0.0722 - accuracy: 0.9917
# Epoch 67/200
# 24/24 - 0s - loss: 0.0695 - accuracy: 0.9917
# Epoch 68/200
# 24/24 - 0s - loss: 0.0705 - accuracy: 0.9917
# Epoch 69/200
# 24/24 - 0s - loss: 0.0678 - accuracy: 0.9917
# Epoch 70/200
# 24/24 - 0s - loss: 0.0651 - accuracy: 0.9917
# Epoch 71/200
# 24/24 - 0s - loss: 0.0648 - accuracy: 0.9917
# Epoch 72/200
# 24/24 - 0s - loss: 0.0637 - accuracy: 0.9917
# Epoch 73/200
# 24/24 - 0s - loss: 0.0622 - accuracy: 0.9917
# Epoch 74/200
# 24/24 - 0s - loss: 0.0603 - accuracy: 0.9917
# Epoch 75/200
# 24/24 - 0s - loss: 0.0602 - accuracy: 0.9917
# Epoch 76/200
# 24/24 - 0s - loss: 0.0595 - accuracy: 0.9917
# Epoch 77/200
# 24/24 - 0s - loss: 0.0592 - accuracy: 0.9917
# Epoch 78/200
# 24/24 - 0s - loss: 0.0585 - accuracy: 0.9917
# Epoch 79/200
# 24/24 - 0s - loss: 0.0561 - accuracy: 0.9917
# Epoch 80/200
# 24/24 - 0s - loss: 0.0582 - accuracy: 0.9917
# Epoch 81/200
# 24/24 - 0s - loss: 0.0554 - accuracy: 0.9917
# Epoch 82/200
# 24/24 - 0s - loss: 0.0541 - accuracy: 0.9917
# Epoch 83/200
# 24/24 - 0s - loss: 0.0547 - accuracy: 0.9917
# Epoch 84/200
# 24/24 - 0s - loss: 0.0540 - accuracy: 0.9917
# Epoch 85/200
# 24/24 - 0s - loss: 0.0537 - accuracy: 0.9917
# Epoch 86/200
# 24/24 - 0s - loss: 0.0557 - accuracy: 0.9917
# Epoch 87/200
# 24/24 - 0s - loss: 0.0508 - accuracy: 0.9917
# Epoch 88/200
# 24/24 - 0s - loss: 0.0517 - accuracy: 0.9917
# Epoch 89/200
# 24/24 - 0s - loss: 0.0518 - accuracy: 0.9917
# Epoch 90/200
# 24/24 - 0s - loss: 0.0494 - accuracy: 0.9917
# Epoch 91/200
# 24/24 - 0s - loss: 0.0518 - accuracy: 0.9917
# Epoch 92/200
# 24/24 - 0s - loss: 0.0491 - accuracy: 0.9917
# Epoch 93/200
# 24/24 - 0s - loss: 0.0471 - accuracy: 0.9917
# Epoch 94/200
# 24/24 - 0s - loss: 0.0475 - accuracy: 0.9917
# Epoch 95/200
# 24/24 - 0s - loss: 0.0473 - accuracy: 0.9917
# Epoch 96/200
# 24/24 - 0s - loss: 0.0469 - accuracy: 0.9917
# Epoch 97/200
# 24/24 - 0s - loss: 0.0455 - accuracy: 0.9917
# Epoch 98/200
# 24/24 - 0s - loss: 0.0457 - accuracy: 0.9917
# Epoch 99/200
# 24/24 - 0s - loss: 0.0460 - accuracy: 0.9917
# Epoch 100/200
# 24/24 - 0s - loss: 0.0462 - accuracy: 0.9917
# Epoch 101/200
# 24/24 - 0s - loss: 0.0470 - accuracy: 0.9917
# Epoch 102/200
# 24/24 - 0s - loss: 0.0444 - accuracy: 0.9917
# Epoch 103/200
# 24/24 - 0s - loss: 0.0434 - accuracy: 0.9917
# Epoch 104/200
# 24/24 - 0s - loss: 0.0438 - accuracy: 0.9917
# Epoch 105/200
# 24/24 - 0s - loss: 0.0434 - accuracy: 0.9917
# Epoch 106/200
# 24/24 - 0s - loss: 0.0451 - accuracy: 0.9917
# Epoch 107/200
# 24/24 - 0s - loss: 0.0429 - accuracy: 0.9917
# Epoch 108/200
# 24/24 - 0s - loss: 0.0437 - accuracy: 0.9917
# Epoch 109/200
# 24/24 - 0s - loss: 0.0454 - accuracy: 0.9917
# Epoch 110/200
# 24/24 - 0s - loss: 0.0419 - accuracy: 0.9917
# Epoch 111/200
# 24/24 - 0s - loss: 0.0416 - accuracy: 0.9917
# Epoch 112/200
# 24/24 - 0s - loss: 0.0412 - accuracy: 0.9917
# Epoch 113/200
# 24/24 - 0s - loss: 0.0436 - accuracy: 0.9917
# Epoch 114/200
# 24/24 - 0s - loss: 0.0411 - accuracy: 0.9917
# Epoch 115/200
# 24/24 - 0s - loss: 0.0408 - accuracy: 0.9917
# Epoch 116/200
# 24/24 - 0s - loss: 0.0420 - accuracy: 0.9917
# Epoch 117/200
# 24/24 - 0s - loss: 0.0405 - accuracy: 0.9917
# Epoch 118/200
# 24/24 - 0s - loss: 0.0429 - accuracy: 0.9917
# Epoch 119/200
# 24/24 - 0s - loss: 0.0420 - accuracy: 0.9917
# Epoch 120/200
# 24/24 - 0s - loss: 0.0392 - accuracy: 0.9917
# Epoch 121/200
# 24/24 - 0s - loss: 0.0391 - accuracy: 0.9917
# Epoch 122/200
# 24/24 - 0s - loss: 0.0396 - accuracy: 0.9917
# Epoch 123/200
# 24/24 - 0s - loss: 0.0401 - accuracy: 0.9917
# Epoch 124/200
# 24/24 - 0s - loss: 0.0397 - accuracy: 0.9917
# Epoch 125/200
# 24/24 - 0s - loss: 0.0388 - accuracy: 0.9917
# Epoch 126/200
# 24/24 - 0s - loss: 0.0416 - accuracy: 0.9917
# Epoch 127/200
# 24/24 - 0s - loss: 0.0371 - accuracy: 0.9917
# Epoch 128/200
# 24/24 - 0s - loss: 0.0401 - accuracy: 0.9917
# Epoch 129/200
# 24/24 - 0s - loss: 0.0395 - accuracy: 0.9917
# Epoch 130/200
# 24/24 - 0s - loss: 0.0389 - accuracy: 0.9917
# Epoch 131/200
# 24/24 - 0s - loss: 0.0371 - accuracy: 0.9917
# Epoch 132/200
# 24/24 - 0s - loss: 0.0373 - accuracy: 0.9917
# Epoch 133/200
# 24/24 - 0s - loss: 0.0369 - accuracy: 0.9917
# Epoch 134/200
# 24/24 - 0s - loss: 0.0366 - accuracy: 0.9917
# Epoch 135/200
# 24/24 - 0s - loss: 0.0367 - accuracy: 0.9917
# Epoch 136/200
# 24/24 - 0s - loss: 0.0361 - accuracy: 0.9917
# Epoch 137/200
# 24/24 - 0s - loss: 0.0361 - accuracy: 0.9917
# Epoch 138/200
# 24/24 - 0s - loss: 0.0359 - accuracy: 0.9917
# Epoch 139/200
# 24/24 - 0s - loss: 0.0358 - accuracy: 0.9917
# Epoch 140/200
# 24/24 - 0s - loss: 0.0364 - accuracy: 0.9917
# Epoch 141/200
# 24/24 - 0s - loss: 0.0374 - accuracy: 0.9917
# Epoch 142/200
# 24/24 - 0s - loss: 0.0419 - accuracy: 0.9917
# Epoch 143/200
# 24/24 - 0s - loss: 0.0406 - accuracy: 0.9917
# Epoch 144/200
# 24/24 - 0s - loss: 0.0328 - accuracy: 0.9917
# Epoch 145/200
# 24/24 - 0s - loss: 0.0349 - accuracy: 0.9917
# Epoch 146/200
# 24/24 - 0s - loss: 0.0377 - accuracy: 0.9917
# Epoch 147/200
# 24/24 - 0s - loss: 0.0350 - accuracy: 0.9917
# Epoch 148/200
# 24/24 - 0s - loss: 0.0342 - accuracy: 0.9917
# Epoch 149/200
# 24/24 - 0s - loss: 0.0355 - accuracy: 0.9917
# Epoch 150/200
# 24/24 - 0s - loss: 0.0343 - accuracy: 0.9917
# Epoch 151/200
# 24/24 - 0s - loss: 0.0352 - accuracy: 0.9917
# Epoch 152/200
# 24/24 - 0s - loss: 0.0353 - accuracy: 0.9917
# Epoch 153/200
# 24/24 - 0s - loss: 0.0350 - accuracy: 0.9917
# Epoch 154/200
# 24/24 - 0s - loss: 0.0328 - accuracy: 0.9917
# Epoch 155/200
# 24/24 - 0s - loss: 0.0343 - accuracy: 0.9917
# Epoch 156/200
# 24/24 - 0s - loss: 0.0328 - accuracy: 0.9917
# Epoch 157/200
# 24/24 - 0s - loss: 0.0341 - accuracy: 0.9917
# Epoch 158/200
# 24/24 - 0s - loss: 0.0363 - accuracy: 0.9917
# Epoch 159/200
# 24/24 - 0s - loss: 0.0339 - accuracy: 0.9917
# Epoch 160/200
# 24/24 - 0s - loss: 0.0337 - accuracy: 0.9917
# Epoch 161/200
# 24/24 - 0s - loss: 0.0361 - accuracy: 0.9917
# Epoch 162/200
# 24/24 - 0s - loss: 0.0357 - accuracy: 0.9917
# Epoch 163/200
# 24/24 - 0s - loss: 0.0329 - accuracy: 0.9917
# Epoch 164/200
# 24/24 - 0s - loss: 0.0326 - accuracy: 0.9917
# Epoch 165/200
# 24/24 - 0s - loss: 0.0337 - accuracy: 0.9917
# Epoch 166/200
# 24/24 - 0s - loss: 0.0332 - accuracy: 0.9917
# Epoch 167/200
# 24/24 - 0s - loss: 0.0349 - accuracy: 0.9917
# Epoch 168/200
# 24/24 - 0s - loss: 0.0355 - accuracy: 0.9917
# Epoch 169/200
# 24/24 - 0s - loss: 0.0308 - accuracy: 0.9917
# Epoch 170/200
# 24/24 - 0s - loss: 0.0326 - accuracy: 0.9917
# Epoch 171/200
# 24/24 - 0s - loss: 0.0320 - accuracy: 0.9917
# Epoch 172/200
# 24/24 - 0s - loss: 0.0341 - accuracy: 0.9917
# Epoch 173/200
# 24/24 - 0s - loss: 0.0320 - accuracy: 0.9917
# Epoch 174/200
# 24/24 - 0s - loss: 0.0315 - accuracy: 0.9917
# Epoch 175/200
# 24/24 - 0s - loss: 0.0324 - accuracy: 0.9917
# Epoch 176/200
# 24/24 - 0s - loss: 0.0318 - accuracy: 0.9917
# Epoch 177/200
# 24/24 - 0s - loss: 0.0314 - accuracy: 0.9917
# Epoch 178/200
# 24/24 - 0s - loss: 0.0312 - accuracy: 0.9917
# Epoch 179/200
# 24/24 - 0s - loss: 0.0313 - accuracy: 0.9917
# Epoch 180/200
# 24/24 - 0s - loss: 0.0314 - accuracy: 0.9917
# Epoch 181/200
# 24/24 - 0s - loss: 0.0306 - accuracy: 0.9917
# Epoch 182/200
# 24/24 - 0s - loss: 0.0318 - accuracy: 0.9917
# Epoch 183/200
# 24/24 - 0s - loss: 0.0318 - accuracy: 0.9917
# Epoch 184/200
# 24/24 - 0s - loss: 0.0326 - accuracy: 0.9917
# Epoch 185/200
# 24/24 - 0s - loss: 0.0321 - accuracy: 0.9917
# Epoch 186/200
# 24/24 - 0s - loss: 0.0313 - accuracy: 0.9917
# Epoch 187/200
# 24/24 - 0s - loss: 0.0360 - accuracy: 0.9917
# Epoch 188/200
# 24/24 - 0s - loss: 0.0342 - accuracy: 0.9917
# Epoch 189/200
# 24/24 - 0s - loss: 0.0304 - accuracy: 0.9917
# Epoch 190/200
# 24/24 - 0s - loss: 0.0304 - accuracy: 0.9917
# Epoch 191/200
# 24/24 - 0s - loss: 0.0305 - accuracy: 0.9917
# Epoch 192/200
# 24/24 - 0s - loss: 0.0309 - accuracy: 0.9917
# Epoch 193/200
# 24/24 - 0s - loss: 0.0319 - accuracy: 0.9917
# Epoch 194/200
# 24/24 - 0s - loss: 0.0321 - accuracy: 0.9917
# Epoch 195/200
# 24/24 - 0s - loss: 0.0314 - accuracy: 0.9917
# Epoch 196/200
# 24/24 - 0s - loss: 0.0313 - accuracy: 0.9917
# Epoch 197/200
# 24/24 - 0s - loss: 0.0324 - accuracy: 0.9917
# Epoch 198/200
# 24/24 - 0s - loss: 0.0301 - accuracy: 0.9917
# Epoch 199/200
# 24/24 - 0s - loss: 0.0297 - accuracy: 0.9917
# Epoch 200/200
# 24/24 - 0s - loss: 0.0295 - accuracy: 0.9917
# WARNING:tensorflow:Model was constructed with shape (None, 5, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5, 2), dtype=tf.float32, name='fc1_input'), name='fc1_input', description="created by layer 'fc1_input'"), but it was called on an input with incompatible shape (None, 2).
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0164 - accuracy: 1.0000
# Final test set loss: 0.016380
# Final test set accuracy: 1.000000
