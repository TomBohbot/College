# %%
# Required import statements:
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.regularizers import l2

# %%
# load the iris dataset: 
iris_data = load_iris()

# %%
# Set x as flower characteristics and y as target values:
x = iris_data.data[:,[2,3] ]            # Use only 2 characteristics from the iris dataset.
y_ = iris_data.target.reshape(-1, 1) # Remove == 0 from previous HW to have mulitple types, instead of just 1 and 0.

# %%
# One Hot encode the class labels:
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)

# %%
# Split the data for training and testing:
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %%
# Build the model:
model = Sequential()
model.add(Dense(10, input_shape=(2,), activation='relu', name='fc1', bias_regularizer=l2(0.01)))
model.add(Dense(10, activation='relu', name='fc2', bias_regularizer=l2(0.01)))
model.add(Dense(3, activation='softmax', name='output', bias_regularizer=l2(0.01)))

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Print summary:
print('Neural Network Model Summary: ')
print(model.summary())
# Out:
# Neural Network Model Summary:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 10)                30
# _________________________________________________________________
# fc2 (Dense)                  (None, 10)                110
# _________________________________________________________________
# output (Dense)               (None, 3)                 33
# =================================================================
# Total params: 173
# Trainable params: 173
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# Epoch 1/200
# 24/24 - 0s - loss: 1.1906 - accuracy: 0.5083
# Epoch 2/200
# 24/24 - 0s - loss: 1.0905 - accuracy: 0.3500
# Epoch 3/200
# 24/24 - 0s - loss: 1.0330 - accuracy: 0.3500
# Epoch 4/200
# 24/24 - 0s - loss: 0.9940 - accuracy: 0.3500
# Epoch 5/200
# 24/24 - 0s - loss: 0.9654 - accuracy: 0.3500
# Epoch 6/200
# 24/24 - 0s - loss: 0.9448 - accuracy: 0.3500
# Epoch 7/200
# 24/24 - 0s - loss: 0.9260 - accuracy: 0.3500
# Epoch 8/200
# 24/24 - 0s - loss: 0.9105 - accuracy: 0.3500
# Epoch 9/200
# 24/24 - 0s - loss: 0.8937 - accuracy: 0.3500
# Epoch 10/200
# 24/24 - 0s - loss: 0.8764 - accuracy: 0.3500
# Epoch 11/200
# 24/24 - 0s - loss: 0.8647 - accuracy: 0.3583
# Epoch 12/200
# 24/24 - 0s - loss: 0.8458 - accuracy: 0.3583
# Epoch 13/200
# 24/24 - 0s - loss: 0.8382 - accuracy: 0.4000
# Epoch 14/200
# 24/24 - 0s - loss: 0.8170 - accuracy: 0.4750
# Epoch 15/200
# 24/24 - 0s - loss: 0.8027 - accuracy: 0.5917
# Epoch 16/200
# 24/24 - 0s - loss: 0.7911 - accuracy: 0.6167
# Epoch 17/200
# 24/24 - 0s - loss: 0.7752 - accuracy: 0.6583
# Epoch 18/200
# 24/24 - 0s - loss: 0.7612 - accuracy: 0.6583
# Epoch 19/200
# 24/24 - 0s - loss: 0.7480 - accuracy: 0.6667
# Epoch 20/200
# 24/24 - 0s - loss: 0.7338 - accuracy: 0.7000
# Epoch 21/200
# 24/24 - 0s - loss: 0.7216 - accuracy: 0.7083
# Epoch 22/200
# 24/24 - 0s - loss: 0.7089 - accuracy: 0.7167
# Epoch 23/200
# 24/24 - 0s - loss: 0.6964 - accuracy: 0.7167
# Epoch 24/200
# 24/24 - 0s - loss: 0.6838 - accuracy: 0.7250
# Epoch 25/200
# 24/24 - 0s - loss: 0.6695 - accuracy: 0.7250
# Epoch 26/200
# 24/24 - 0s - loss: 0.6564 - accuracy: 0.7250
# Epoch 27/200
# 24/24 - 0s - loss: 0.6311 - accuracy: 0.7333
# Epoch 28/200
# 24/24 - 0s - loss: 0.6069 - accuracy: 0.7417
# Epoch 29/200
# 24/24 - 0s - loss: 0.5860 - accuracy: 0.7167
# Epoch 30/200
# 24/24 - 0s - loss: 0.5640 - accuracy: 0.7500
# Epoch 31/200
# 24/24 - 0s - loss: 0.5493 - accuracy: 0.7250
# Epoch 32/200
# 24/24 - 0s - loss: 0.5290 - accuracy: 0.8167
# Epoch 33/200
# 24/24 - 0s - loss: 0.5136 - accuracy: 0.8000
# Epoch 34/200
# 24/24 - 0s - loss: 0.4990 - accuracy: 0.7667
# Epoch 35/200
# 24/24 - 0s - loss: 0.4878 - accuracy: 0.8417
# Epoch 36/200
# 24/24 - 0s - loss: 0.4766 - accuracy: 0.8083
# Epoch 37/200
# 24/24 - 0s - loss: 0.4688 - accuracy: 0.8667
# Epoch 38/200
# 24/24 - 0s - loss: 0.4585 - accuracy: 0.7833
# Epoch 39/200
# 24/24 - 0s - loss: 0.4500 - accuracy: 0.8333
# Epoch 40/200
# 24/24 - 0s - loss: 0.4417 - accuracy: 0.8583
# Epoch 41/200
# 24/24 - 0s - loss: 0.4369 - accuracy: 0.8917
# Epoch 42/200
# 24/24 - 0s - loss: 0.4305 - accuracy: 0.8417
# Epoch 43/200
# 24/24 - 0s - loss: 0.4241 - accuracy: 0.8500
# Epoch 44/200
# 24/24 - 0s - loss: 0.4204 - accuracy: 0.8917
# Epoch 45/200
# 24/24 - 0s - loss: 0.4117 - accuracy: 0.9000
# Epoch 46/200
# 24/24 - 0s - loss: 0.4059 - accuracy: 0.8667
# Epoch 47/200
# 24/24 - 0s - loss: 0.4006 - accuracy: 0.8417
# Epoch 48/200
# 24/24 - 0s - loss: 0.3978 - accuracy: 0.9333
# Epoch 49/200
# 24/24 - 0s - loss: 0.3829 - accuracy: 0.8917
# Epoch 50/200
# 24/24 - 0s - loss: 0.3795 - accuracy: 0.8667
# Epoch 51/200
# 24/24 - 0s - loss: 0.3737 - accuracy: 0.9167
# Epoch 52/200
# 24/24 - 0s - loss: 0.3683 - accuracy: 0.9333
# Epoch 53/200
# 24/24 - 0s - loss: 0.3659 - accuracy: 0.9167
# Epoch 54/200
# 24/24 - 0s - loss: 0.3615 - accuracy: 0.9083
# Epoch 55/200
# 24/24 - 0s - loss: 0.3611 - accuracy: 0.8750
# Epoch 56/200
# 24/24 - 0s - loss: 0.3551 - accuracy: 0.9000
# Epoch 57/200
# 24/24 - 0s - loss: 0.3542 - accuracy: 0.9417
# Epoch 58/200
# 24/24 - 0s - loss: 0.3490 - accuracy: 0.8833
# Epoch 59/200
# 24/24 - 0s - loss: 0.3469 - accuracy: 0.9333
# Epoch 60/200
# 24/24 - 0s - loss: 0.3463 - accuracy: 0.9083
# Epoch 61/200
# 24/24 - 0s - loss: 0.3433 - accuracy: 0.9333
# Epoch 62/200
# 24/24 - 0s - loss: 0.3390 - accuracy: 0.9417
# Epoch 63/200
# 24/24 - 0s - loss: 0.3369 - accuracy: 0.9417
# Epoch 64/200
# 24/24 - 0s - loss: 0.3325 - accuracy: 0.9333
# Epoch 65/200
# 24/24 - 0s - loss: 0.3355 - accuracy: 0.9500
# Epoch 66/200
# 24/24 - 0s - loss: 0.3351 - accuracy: 0.9083
# Epoch 67/200
# 24/24 - 0s - loss: 0.3261 - accuracy: 0.9417
# Epoch 68/200
# 24/24 - 0s - loss: 0.3223 - accuracy: 0.9417
# Epoch 69/200
# 24/24 - 0s - loss: 0.3201 - accuracy: 0.9417
# Epoch 70/200
# 24/24 - 0s - loss: 0.3187 - accuracy: 0.9417
# Epoch 71/200
# 24/24 - 0s - loss: 0.3172 - accuracy: 0.9500
# Epoch 72/200
# 24/24 - 0s - loss: 0.3155 - accuracy: 0.9000
# Epoch 73/200
# 24/24 - 0s - loss: 0.3142 - accuracy: 0.9417
# Epoch 74/200
# 24/24 - 0s - loss: 0.3106 - accuracy: 0.9500
# Epoch 75/200
# 24/24 - 0s - loss: 0.3072 - accuracy: 0.9417
# Epoch 76/200
# 24/24 - 0s - loss: 0.3049 - accuracy: 0.9417
# Epoch 77/200
# 24/24 - 0s - loss: 0.3023 - accuracy: 0.9500
# Epoch 78/200
# 24/24 - 0s - loss: 0.3033 - accuracy: 0.9583
# Epoch 79/200
# 24/24 - 0s - loss: 0.3034 - accuracy: 0.9167
# Epoch 80/200
# 24/24 - 0s - loss: 0.2944 - accuracy: 0.9333
# Epoch 81/200
# 24/24 - 0s - loss: 0.2999 - accuracy: 0.9250
# Epoch 82/200
# 24/24 - 0s - loss: 0.2958 - accuracy: 0.9583
# Epoch 83/200
# 24/24 - 0s - loss: 0.2929 - accuracy: 0.9417
# Epoch 84/200
# 24/24 - 0s - loss: 0.2882 - accuracy: 0.9417
# Epoch 85/200
# 24/24 - 0s - loss: 0.2855 - accuracy: 0.9500
# Epoch 86/200
# 24/24 - 0s - loss: 0.2845 - accuracy: 0.9417
# Epoch 87/200
# 24/24 - 0s - loss: 0.2898 - accuracy: 0.9167
# Epoch 88/200
# 24/24 - 0s - loss: 0.2857 - accuracy: 0.9583
# Epoch 89/200
# 24/24 - 0s - loss: 0.2790 - accuracy: 0.9417
# Epoch 90/200
# 24/24 - 0s - loss: 0.2782 - accuracy: 0.9500
# Epoch 91/200
# 24/24 - 0s - loss: 0.2810 - accuracy: 0.9500
# Epoch 92/200
# 24/24 - 0s - loss: 0.2765 - accuracy: 0.9417
# Epoch 93/200
# 24/24 - 0s - loss: 0.2750 - accuracy: 0.9417
# Epoch 94/200
# 24/24 - 0s - loss: 0.2708 - accuracy: 0.9500
# Epoch 95/200
# 24/24 - 0s - loss: 0.2713 - accuracy: 0.9417
# Epoch 96/200
# 24/24 - 0s - loss: 0.2691 - accuracy: 0.9583
# Epoch 97/200
# 24/24 - 0s - loss: 0.2684 - accuracy: 0.9417
# Epoch 98/200
# 24/24 - 0s - loss: 0.2646 - accuracy: 0.9583
# Epoch 99/200
# 24/24 - 0s - loss: 0.2627 - accuracy: 0.9583
# Epoch 100/200
# 24/24 - 0s - loss: 0.2642 - accuracy: 0.9417
# Epoch 101/200
# 24/24 - 0s - loss: 0.2631 - accuracy: 0.9583
# Epoch 102/200
# 24/24 - 0s - loss: 0.2589 - accuracy: 0.9583
# Epoch 103/200
# 24/24 - 0s - loss: 0.2598 - accuracy: 0.9583
# Epoch 104/200
# 24/24 - 0s - loss: 0.2544 - accuracy: 0.9500
# Epoch 105/200
# 24/24 - 0s - loss: 0.2539 - accuracy: 0.9583
# Epoch 106/200
# 24/24 - 0s - loss: 0.2528 - accuracy: 0.9583
# Epoch 107/200
# 24/24 - 0s - loss: 0.2509 - accuracy: 0.9417
# Epoch 108/200
# 24/24 - 0s - loss: 0.2547 - accuracy: 0.9583
# Epoch 109/200
# 24/24 - 0s - loss: 0.2489 - accuracy: 0.9417
# Epoch 110/200
# 24/24 - 0s - loss: 0.2492 - accuracy: 0.9583
# Epoch 111/200
# 24/24 - 0s - loss: 0.2503 - accuracy: 0.9417
# Epoch 112/200
# 24/24 - 0s - loss: 0.2478 - accuracy: 0.9417
# Epoch 113/200
# 24/24 - 0s - loss: 0.2408 - accuracy: 0.9583
# Epoch 114/200
# 24/24 - 0s - loss: 0.2436 - accuracy: 0.9583
# Epoch 115/200
# 24/24 - 0s - loss: 0.2477 - accuracy: 0.9500
# Epoch 116/200
# 24/24 - 0s - loss: 0.2403 - accuracy: 0.9583
# Epoch 117/200
# 24/24 - 0s - loss: 0.2413 - accuracy: 0.9583
# Epoch 118/200
# 24/24 - 0s - loss: 0.2373 - accuracy: 0.9583
# Epoch 119/200
# 24/24 - 0s - loss: 0.2382 - accuracy: 0.9417
# Epoch 120/200
# 24/24 - 0s - loss: 0.2360 - accuracy: 0.9583
# Epoch 121/200
# 24/24 - 0s - loss: 0.2340 - accuracy: 0.9583
# Epoch 122/200
# 24/24 - 0s - loss: 0.2350 - accuracy: 0.9583
# Epoch 123/200
# 24/24 - 0s - loss: 0.2321 - accuracy: 0.9583
# Epoch 124/200
# 24/24 - 0s - loss: 0.2329 - accuracy: 0.9417
# Epoch 125/200
# 24/24 - 0s - loss: 0.2317 - accuracy: 0.9583
# Epoch 126/200
# 24/24 - 0s - loss: 0.2325 - accuracy: 0.9500
# Epoch 127/200
# 24/24 - 0s - loss: 0.2290 - accuracy: 0.9583
# Epoch 128/200
# 24/24 - 0s - loss: 0.2278 - accuracy: 0.9500
# Epoch 129/200
# 24/24 - 0s - loss: 0.2275 - accuracy: 0.9500
# Epoch 130/200
# 24/24 - 0s - loss: 0.2264 - accuracy: 0.9500
# Epoch 131/200
# 24/24 - 0s - loss: 0.2293 - accuracy: 0.9500
# Epoch 132/200
# 24/24 - 0s - loss: 0.2255 - accuracy: 0.9583
# Epoch 133/200
# 24/24 - 0s - loss: 0.2251 - accuracy: 0.9583
# Epoch 134/200
# 24/24 - 0s - loss: 0.2277 - accuracy: 0.9417
# Epoch 135/200
# 24/24 - 0s - loss: 0.2245 - accuracy: 0.9500
# Epoch 136/200
# 24/24 - 0s - loss: 0.2213 - accuracy: 0.9583
# Epoch 137/200
# 24/24 - 0s - loss: 0.2200 - accuracy: 0.9583
# Epoch 138/200
# 24/24 - 0s - loss: 0.2208 - accuracy: 0.9500
# Epoch 139/200
# 24/24 - 0s - loss: 0.2209 - accuracy: 0.9583
# Epoch 140/200
# 24/24 - 0s - loss: 0.2194 - accuracy: 0.9583
# Epoch 141/200
# 24/24 - 0s - loss: 0.2177 - accuracy: 0.9583
# Epoch 142/200
# 24/24 - 0s - loss: 0.2194 - accuracy: 0.9417
# Epoch 143/200
# 24/24 - 0s - loss: 0.2179 - accuracy: 0.9583
# Epoch 144/200
# 24/24 - 0s - loss: 0.2234 - accuracy: 0.9500
# Epoch 145/200
# 24/24 - 0s - loss: 0.2169 - accuracy: 0.9583
# Epoch 146/200
# 24/24 - 0s - loss: 0.2143 - accuracy: 0.9500
# Epoch 147/200
# 24/24 - 0s - loss: 0.2127 - accuracy: 0.9583
# Epoch 148/200
# 24/24 - 0s - loss: 0.2148 - accuracy: 0.9583
# Epoch 149/200
# 24/24 - 0s - loss: 0.2131 - accuracy: 0.9500
# Epoch 150/200
# 24/24 - 0s - loss: 0.2131 - accuracy: 0.9500
# Epoch 151/200
# 24/24 - 0s - loss: 0.2109 - accuracy: 0.9583
# Epoch 152/200
# 24/24 - 0s - loss: 0.2130 - accuracy: 0.9583
# Epoch 153/200
# 24/24 - 0s - loss: 0.2111 - accuracy: 0.9583
# Epoch 154/200
# 24/24 - 0s - loss: 0.2104 - accuracy: 0.9583
# Epoch 155/200
# 24/24 - 0s - loss: 0.2108 - accuracy: 0.9417
# Epoch 156/200
# 24/24 - 0s - loss: 0.2094 - accuracy: 0.9500
# Epoch 157/200
# 24/24 - 0s - loss: 0.2178 - accuracy: 0.9583
# Epoch 158/200
# 24/24 - 0s - loss: 0.2099 - accuracy: 0.9417
# Epoch 159/200
# 24/24 - 0s - loss: 0.2095 - accuracy: 0.9583
# Epoch 160/200
# 24/24 - 0s - loss: 0.2095 - accuracy: 0.9583
# Epoch 161/200
# 24/24 - 0s - loss: 0.2119 - accuracy: 0.9500
# Epoch 162/200
# 24/24 - 0s - loss: 0.2095 - accuracy: 0.9583
# Epoch 163/200
# 24/24 - 0s - loss: 0.2109 - accuracy: 0.9500
# Epoch 164/200
# 24/24 - 0s - loss: 0.2070 - accuracy: 0.9500
# Epoch 165/200
# 24/24 - 0s - loss: 0.2039 - accuracy: 0.9583
# Epoch 166/200
# 24/24 - 0s - loss: 0.2017 - accuracy: 0.9583
# Epoch 167/200
# 24/24 - 0s - loss: 0.2028 - accuracy: 0.9583
# Epoch 168/200
# 24/24 - 0s - loss: 0.2030 - accuracy: 0.9583
# Epoch 169/200
# 24/24 - 0s - loss: 0.2037 - accuracy: 0.9583
# Epoch 170/200
# 24/24 - 0s - loss: 0.2032 - accuracy: 0.9583
# Epoch 171/200
# 24/24 - 0s - loss: 0.2030 - accuracy: 0.9417
# Epoch 172/200
# 24/24 - 0s - loss: 0.2020 - accuracy: 0.9583
# Epoch 173/200
# 24/24 - 0s - loss: 0.2009 - accuracy: 0.9583
# Epoch 174/200
# 24/24 - 0s - loss: 0.1999 - accuracy: 0.9417
# Epoch 175/200
# 24/24 - 0s - loss: 0.2042 - accuracy: 0.9417
# Epoch 176/200
# 24/24 - 0s - loss: 0.2062 - accuracy: 0.9500
# Epoch 177/200
# 24/24 - 0s - loss: 0.1994 - accuracy: 0.9583
# Epoch 178/200
# 24/24 - 0s - loss: 0.1979 - accuracy: 0.9583
# Epoch 179/200
# 24/24 - 0s - loss: 0.2046 - accuracy: 0.9417
# Epoch 180/200
# 24/24 - 0s - loss: 0.1979 - accuracy: 0.9583
# Epoch 181/200
# 24/24 - 0s - loss: 0.1974 - accuracy: 0.9583
# Epoch 182/200
# 24/24 - 0s - loss: 0.1962 - accuracy: 0.9583
# Epoch 183/200
# 24/24 - 0s - loss: 0.1982 - accuracy: 0.9583
# Epoch 184/200
# 24/24 - 0s - loss: 0.2030 - accuracy: 0.9417
# Epoch 185/200
# 24/24 - 0s - loss: 0.1979 - accuracy: 0.9583
# Epoch 186/200
# 24/24 - 0s - loss: 0.1965 - accuracy: 0.9583
# Epoch 187/200
# 24/24 - 0s - loss: 0.1950 - accuracy: 0.9583
# Epoch 188/200
# 24/24 - 0s - loss: 0.1927 - accuracy: 0.9583
# Epoch 189/200
# 24/24 - 0s - loss: 0.1943 - accuracy: 0.9583
# Epoch 190/200
# 24/24 - 0s - loss: 0.2002 - accuracy: 0.9500
# Epoch 191/200
# 24/24 - 0s - loss: 0.1920 - accuracy: 0.9583
# Epoch 192/200
# 24/24 - 0s - loss: 0.1922 - accuracy: 0.9583
# Epoch 193/200
# 24/24 - 0s - loss: 0.1938 - accuracy: 0.9583
# Epoch 194/200
# 24/24 - 0s - loss: 0.1932 - accuracy: 0.9583
# Epoch 195/200
# 24/24 - 0s - loss: 0.1928 - accuracy: 0.9583
# Epoch 196/200
# 24/24 - 0s - loss: 0.1909 - accuracy: 0.9583
# Epoch 197/200
# 24/24 - 0s - loss: 0.1902 - accuracy: 0.9583
# Epoch 198/200
# 24/24 - 0s - loss: 0.1904 - accuracy: 0.9583
# Epoch 199/200
# 24/24 - 0s - loss: 0.1892 - accuracy: 0.9583
# Epoch 200/200
# 24/24 - 0s - loss: 0.1938 - accuracy: 0.9583

# %%
# Test on unseen data
results = model.evaluate(test_x, test_y)
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# 1/1 [==============================] - 0s 138ms/step - loss: 0.1545 - accuracy: 0.9667
# Final test set loss: 0.154546
# Final test set accuracy: 0.966667
